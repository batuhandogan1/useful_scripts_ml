# %%
import os
import cv2
import hashlib

def dhash(image, hash_size=8):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray, (hash_size + 1, hash_size))
    diff = resized[:, 1:] > resized[:, :-1]
    return sum([2 ** i for (i, v) in enumerate(diff.flatten()) if v])

def find_duplicate_images(folder_path):
    images_hashes = {}
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        image = cv2.imread(file_path)
        if image is None:
            print(f"{filename} bir fotoğraf değil, atlanıyor.")
            continue
        
        image_hash = dhash(image)
        
        if image_hash in images_hashes:
            original_image = images_hashes[image_hash]
            print(f"{filename} ve {original_image} aynı, {filename} siliniyor.")
            os.remove(file_path)
        else:
            images_hashes[image_hash] = filename

folder_path = "/home/bdogan/all_files/ekin_files/gun_detection/gun_detection_stage_1_dataset/part_2/"
find_duplicate_images(folder_path)
# Out:
# 49d1ce29.txt bir fotoğraf değil, atlanıyor.
# 2423b7df.txt bir fotoğraf değil, atlanıyor.
# 22826ef4.txt bir fotoğraf değil, atlanıyor.
# 21336c33.txt bir fotoğraf değil, atlanıyor.
# 42d5481b.txt bir fotoğraf değil, atlanıyor.
# 7c70d0f4.txt bir fotoğraf değil, atlanıyor.
# 51306024.txt bir fotoğraf değil, atlanıyor.
# 13c766f3.txt bir fotoğraf değil, atlanıyor.
# 0cfe2640.txt bir fotoğraf değil, atlanıyor.
# 166ddc9a.txt bir fotoğraf değil, atlanıyor.
# 5cdc09d6.txt bir fotoğraf değil, atlanıyor.
# 126bff86.txt bir fotoğraf değil, atlanıyor.
# 2b442421.txt bir fotoğraf değil, atlanıyor.
# 507cb00d.txt bir fotoğraf değil, atlanıyor.
# 46293f4d.txt bir fotoğraf değil, atlanıyor.
# 555023f3.txt bir fotoğraf değil, atlanıyor.
# 18642077.txt bir fotoğraf değil, atlanıyor.
# 5f0a48e1.txt bir fotoğraf değil, atlanıyor.
# 46aef398.txt bir fotoğraf değil, atlanıyor.
# 2029d299.txt bir fotoğraf değil, atlanıyor.
# 587ab86d.txt bir fotoğraf değil, atlanıyor.
# ...
